# %% [markdown]
# # Numeric Operations

# %%
result = 32 + 23
result
# Out:
# 55

# %%
19 - 21
# Out:
# -2

# %%
11 * 11
# Out:
# 121

# %%
12 / 32
# Out:
# 0.375

# %%
3 ** 2
# Out:
# 9

# %%
4 + 6 * 5
# Out:
# 34

# %%
(4 + 6) * 5
# Out:
# 50

# %%
# Floor division: The double slash // is called floor division. All it does is perform division and truncate the result.
34 // 4
# Out:
# 8

# %%
# Modulo: the modular division operator, % (also called modulo). This operation is the sibling to //.
# Whereas // returns the truncated result of a division, % returns the remainder of integer division.
34 % 4
# Out:
# 2

# %%
# abs() will return the absolute value of a number
abs(2.14)
# Out:
# 2.14

# %%
abs(-2.14)
# Out:
# 2.14

# %%
# min() and max() will return the minimum respectively maximum of a bunch of numbers 
min(14, 21, 32, 11, 44, 23)
# Out:
# 11

# %%
max(14, 21, 32, 11, 44, 23)
# Out:
# 44

# %%
# and round() will round a number to a given amount of decimals.
round(3.14159265359, 3)
# Out:
# 3.142

# %% [markdown]
# # Variables
# One of the most powerful constructs in programming is the ability to store arbitrary values in what we call variables. You can think of variable assignment as giving a name to something so that it can be accessed later by different parts of your program.
#
# As you may remember, variable assignment in Python occurs with the = operator. To assign a value to a variable name (i.e. declare it), you simply put the variable name on the left side of the = and the value you want to associate with that variable name on the right side. Once this has happened, you can access the value in the variable by using it's name somewhere later in your code or notebook.

# %%
a = 8
b = "Hello"

# %%
b
# Out:
# 'Hello'

# %%
a - 4
# Out:
# 4

# %%
a * b
# Out:
# 'HelloHelloHelloHelloHelloHelloHelloHello'

# %%
b * a
# Out:
# 'HelloHelloHelloHelloHelloHelloHelloHello'

# %%
a = a + 5 # The result of the first line could have been achieved with a += 5
a
# Out:
# 13

# %% [markdown]
# # Types

# %%
type(14)
# Out:
# int

# %%
type(14.32)
# Out:
# float

# %%
type("Hello")
# Out:
# str

# %%
type(complex(5, 6))
# Out:
# complex

# %%
type(12 ** 2)
# Out:
# int

# %%
type(25 // 6)
# Out:
# int

# %%
result = 25 // 6
result
#type(result)
# Out:
# 4

# %%
x = 82
y = 30

# %%
x += y
x
# Out:
# 112

# %%
y = x -3
y
# Out:
# 109

# %%
x -= y - 5
x
# Out:
# 8

# %% [markdown]
# - Calculation of the mean: Person1 is 21 years old, Person2 is 43 years old and Person3 is 19 years old. Define variables for the ages, calculate the mean with them and save the result in another variable. Check which type the result has. Can you round the result to 2 decimals?

# %%
Age1 = 21
Age2 = 43
Age3 = 19
AgeMean = (Age1 + Age2 + Age3) / 3
round(AgeMean, 2)
# Out:
# 27.67

# %% [markdown]
# # Strings
# - For Pyhton Strings have be fe encoded in ASCII, utf-8, or unicode

# %% [markdown]
# String Operations

# %%
'My first string ' + 'My second string'
# Out:
# 'My first string My second string'

# %%
'Repeating string ' * 3
# Out:
# 'Repeating string Repeating string Repeating string '

# %%
'Repeating string Repeating string Repeating string '.strip()
# Out:
# 'Repeating string Repeating string Repeating string'

# %%
' Repeating string Repeating string Repeating string '.strip()
# Out:
# 'Repeating string Repeating string Repeating string'

# %%
'Repeating string Repeating string Repeating string '.strip("R")
# Out:
# 'epeating string Repeating string Repeating string '

# %%
my_str_variable = 'this IS my STRING to PLAY around WITH.'

# %%
my_str_variable.capitalize()
# Out:
# 'This is my string to play around with.'

# %%
my_str_variable.upper()
# Out:
# 'THIS IS MY STRING TO PLAY AROUND WITH.'

# %%
my_str_variable.lower()
# Out:
# 'this is my string to play around with.'

# %%
my_str_variable.replace('STR', 'fl')
# Out:
# 'this IS my flING to PLAY around WITH.'

# %%
my_str_variable.split()
# Out:
# ['this', 'IS', 'my', 'STRING', 'to', 'PLAY', 'around', 'WITH.']

# %%
my_str_variable.split("to")
# Out:
# ['this IS my STRING ', ' PLAY around WITH.']

# %% [markdown]
# Indexing

# %%
my_str_variable = 'Test String'
my_str_variable[1]
# Out:
# 'e'

# %%
my_str_variable[5]
# Out:
# 'S'

# %%
my_str_variable[-1]
# Out:
# 'g'

# %%
my_str_variable[-3]
# Out:
# 'i'

# %%
my_str_variable[1:3]
# Out:
# 'es'

# %%
my_str_variable[5:9]
# Out:
# 'Stri'

# %%
my_str_variable[-6:-1]
# Out:
# 'Strin'

# %%
my_str_variable[1:]
# Out:
# 'est String'

# %%
my_str_variable[:-1]
# Out:
# 'Test Strin'

# %%
my_str_variable[::2]
# Out:
# 'Ts tig'

# %%
my_str_variable[2:10:3]
# Out:
# 'sSi'

# %% [markdown]
# Iteration and Strings
# - We can cycle through all of the letters in our string (a process called iteration) in one of a couple of different ways. Let's first look at cycling through with a while loop.

# %% [markdown]
# While Loop

# %%
my_str, idx = 'hello', 0
while idx < 5:
    print(my_str[idx])
    idx += 1
# Out:
# h
# e
# l
# l
# o

# %%
my_str = 'hello'

len(my_str)
# Out:
# 5

# %%
my_str, idx = 'hello', 0
while idx < len(my_str):
    print(my_str[idx])
    idx += 1
# Out:
# h
# e
# l
# l
# o

# %% [markdown]
# For Loop

# %%
my_str = 'hello'
for idx in range(len(my_str)):
    print(my_str[idx])
# Out:
# h
# e
# l
# l
# o

# %% [markdown]
# Note: the range() function (which we will cover in more depth when we get to functions) as used above simply gives us a list of numbers from 0 up to but not including the inputted number. In the case above, since len(my_str) is 5, range(len(my_str)) returns a list of integers from 0 to 4.
#
# This for loop does the exact same thing as the while loop we wrote above, but with slightly different syntax. How does it work? At each iteration of the loop, idx is assigned one of the values in range(len(my_str)), and then the code within the indented is run with that value of idx. How does Python know what the values of idx will be? Python simply goes through the values of whatever is after the in statement in order, and assigns those values to idx, one at a time through each iteration of the loop. Since range(len(my_str)) returns to us a list of integers from 0 to 4, those values get assigned to idx as we run through the for loop. Let's look at one of our favorite kinds of tables to view this:
#
# After loop #    idx     What's Printed
# 1	            0	    'h'
# 2	            1	    'e'
# 3	            2	    'l'
# 4	            3	    'l'
# 5	            4	    'o'
#
# Note that with our for loop, the idx variable is automatically changed, rather than us having to manually update it (like we did in the while loop). This is one of the incredibly nice aspects of for loops! But wait, it gets even better!

# %%
my_str = 'hello'
for char in my_str:
    print(char)
# Out:
# h
# e
# l
# l
# o

# %% [markdown]
# A Quick Aside on String Formatting

# %%
my_name = 'Sean'
print('Hello %s' % my_name)
print('Hello {}'.format(my_name))
print(f'Hello {my_name}')
# Out:
# Hello Sean
# Hello Sean
# Hello Sean

# %%
print('Hello %s' % my_name)
# Out:
# Hello Sean

# %%
print('Hello {}'.format(my_name))
# Out:
# Hello Sean

# %%
print('Hello {0}'.format(my_name))
# Out:
# Hello Sean

# %%
print('Hello {name}'.format(name=my_name))
# Out:
# Hello Sean

# %%
print(f'Hello {my_name}')
# Out:
# Hello Sean

# %% [markdown]
# String Operation Questions

# %% [markdown]
# 1. When does the distinction between using single and double quotes to build a string matter?
# - When the string itself contains single quote (eg "I don't care")

# %% [markdown]
# 2. Fix the following string to be considered valid and not throw an error when run.
# 'They told me not to do this, but I didn't listen.'
# - "They told me not to do this, but I didn't listen."

# %%
# 3. Create a variable that holds a string of your name.
my_name_is = "Markus"
my_name_is
# Out:
# 'Markus'

# %%
# 4. Create another variable that holds a string of your best friend's name.
friend_name = "I don't have friends"
friend_name
# Out:
# "I don't have friends"

# %%
# 5. Now, use string concatenation (e.g. addition) to add 'Hello, ' before your name.
new_str = "Hello " + my_name_is
new_str
# Out:
# 'Hello Markus'

# %%
# 6. Given the string 'Hello, Sean', replace each of the letter 'e''s with a 't'.
"Hello, Sean".replace("e", "t")
# Out:
# 'Htllo, Stan'

# %%
# 7. Use the .split() method on the string 'Hello, Sean' to split it by the comma (',').
# What happens if you split by a comma and a space (', ')?
"Hello, Sean".split(", ")
# Out:
# ['Hello', 'Sean']

# %% [markdown]
# # if-Statements
